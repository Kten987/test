# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\thinh.lv\Desktop\Adhoc\all_bds_sosanhnha_v2.csv")

# %%
df.shape
# Out:
# (2813, 8)

# %%
df.head(5)
# Out:
#                                                Title                Price  \
# 0              CHO THUÊ CỬA HÀNG, KI ỐT TẠI VIỆT NAM  Giá: 20 triệu/tháng
# 1  CHO THUÊ 5X45M, 1 LẦU MẶT TIỀN MAI VĂN VĨNH, T...  Giá: 55 triệu/tháng
# 2  CHỦ GỬI NHÀ MẶT TIỀN 601 NGUYỄN DUY TRINH QUẬN...  Giá: 24 triệu/tháng
# 3  CHO THUÊ 300M2 CÓ PCCC ĐƯỜNG 4 LÀN TRUNG TÂM B...       Giá: 120 triệu
# 4  CHO THUÊ BIỆT THỰ -12,5X20- MẶT TIỀN NGUYỄN TH...   Giá: 4 triệu/tháng
#
#                 Area                                            address  \
# 0  Diện tích: 225 m²  Đường Mai Văn Vĩnh, Phường Tân Quy, Quận 7, Tp...
# 1  Diện tích: 142 m²  601, Nguyễn Duy Trinh, Phường Bình Trưng Đông ...
# 2  Diện tích: 300 m²  Đường Cầu Diễn, Phường Phúc Diễn, Bắc Từ Liêm,...
# 3  Diện tích: 260 m²  Đường Nguyễn Thành Ý, Phường Đa Kao, Quận 1, T...
# 4   Diện tích: 20 m²  1486A, Đường 3/2, Phường 2, Quận 11, Tp Hồ Chí...
#
#                                                 type  area_value  \
# 0  search?iCat=55&iCitId=0&iDisId=0&iWardId=0&iPr...       225.0
# 1  search?iCat=55&iCitId=0&iDisId=0&iWardId=0&iPr...       142.0
# 2  search?iCat=55&iCitId=0&iDisId=0&iWardId=0&iPr...       300.0
# 3  search?iCat=55&iCitId=0&iDisId=0&iWardId=0&iPr...       260.0
# 4  search?iCat=55&iCitId=0&iDisId=0&iWardId=0&iPr...        20.0
#
#    price_value_trieu  price_per_m2_final
# 0               20.0        88888.888889
# 1               55.0       387323.943662
# 2               24.0        80000.000000
# 3              120.0       461538.461538
# 4                4.0       200000.000000

# %%
df.rename(columns={'Location': 'address'}, inplace=True)

# %%
list_api_keys = ["1EotnhALO_Xf7d5mlOVefECdfpbgPG_Dik0TeOcQauQ",
"92hxCAU523jWUFRXMhM-p3w66P3PxYfY_tZm9pPeShU",
"KwvOafjkobVhF8Iz63lMyNooS-hjaYgmHdZrqVVVHWw",
"N5qb2q5dSfly3fnqWMsDPqVMWUd1yRbTBxbT34hvw_g",
"SsQNhtNfemZJr_FzCYZlub29VeTTjymT3Qm6syC50W8",
"br4m9W3KMhrPa51Vru5M1mWJYCfaVFvWiP3kB2gEQUA",
"spdVYGb-b6cgokZBOuwGG4b3WbmgsxQqv7tudjdOfLc",
"0zeR-GEwo5Od-poIZYTGrw-I80fC2C0b0q4F1Boa8oc",
"UfHD68dH4O9ld-NS22Se6Bls98P9aPZhFq4hA_H7-74",
"c6NrKs_BpAX4OdRFKAVSDeUaQTjSpNF8dCxjcLT6AfE",
"WCpDyLiAACoL9zwSFQQa_HboP-HdWXSM601W1N02aeg",
"faJrm5egL12NmLivrDsbqz44I47DhbJQUIg89L3TdIo",
"cdXQHZ3zzsZv-n04kjimcml7e3BRKcR2H3wl8XPi6SU",
"RBRLSkMgpwy6QF0jKsXs-jXEliqtAwwD_jd0DbHrEN8",
"Dd-n66bTKOIKeQ0H6nRvIOMWatnJ_viPxKMNGpxsFa4",
"q-Ao_RRfZNyfQPp2XsnYGbrOItF6SlXN0jObPIKVnk",
"ufLjrWIrvjyLHzL1TZIEOZjKpgolDMBUPXUwoIblgs0",
"tvjh1g0Xygp6DMsH8n5hX41jgbNh3VE61MsnWHYkfZw",
"d_8_FhktHjeMh91gB9bBKGHgMJFC6auZqHThhlHL9Hw",
"P1RAwTjkXvZUQLjHyi06Zm1YP1KeaZMJdjaNN1ZeOeE",
"DQV3KQ2U9DLoro0jMQUoIr-PQMKBpKIEpOqXzF1A498",
"6IcCytBh4PkKOC3YE2Smw4IGdAyTD7XTtsmgtxF-kdY",
"PgxoArILmRDFQreVp3pC6bexYfcKIVwMMN4oKpa8VOo",
"mwA5L1GvWFvnwIYL-U1kP0RDsZ61ElOKAH7wnbsTs4M"]

# %%
# Hàm gọi api here để lấy thông tin vị trí từ địa chỉ chi tiết
import requests

def get_location(address, api_key ):
    #api_key = "mwA5L1GvWFvnwIYL-U1kP0RDsZ61ElOKAH7wnbsTs4M"

    url = f'https://geocode.search.hereapi.com/v1/geocode?q={address}&apiKey={api_key}'
    
    try:
        # Gửi yêu cầu API
        response = requests.get(url)
        
        # Nếu API key đã hết hạn, thử API key tiếp theo trong danh sách

        if response.status_code == 429:
            return {"lat": "", "lng": "", "House_number": "", "Street": "", "Ward": "", "District": "", "City": "", "progress": "False" }
        else: 
            data = response.json()    
            # Xử lý kết quả và trả về
            if data == {'items': []}: 
                list_address = {"lat": "", "lng": "", "House_number": "", "Street": "", "Ward": "", "District": "", "City": "", "progress": "True" }
            else: 
                result = data['items'][0]
                position = result['position']
                lat = position.get('lat', '')
                long = position.get('lng', '')
                address_info = result['address']
                city = address_info.get('county', '')
                district = address_info.get('city', '')
                ward = address_info.get('district', '')
                street = address_info.get('street', '')
                houseNumber = address_info.get('houseNumber', '')
                list_address = {"lat": lat, "lng": long, "House_number": houseNumber, "Street": street, "Ward": ward, "District": district, "City": city, "progress": "True" }
    except:
           # Nếu thử xảy ra lỗi trả ra tập rỗng và progess là False đánh dấu những case chưa xử lí
        list_address = {"lat": "", "lng": "", "House_number": "", "Street": "", "Ward": "", "District": "", "City": "", "progress": "False" }
           
    return list_address

# Hàm xử lí dữ liệu đầu vào là dataframe
def out_put(df, api_key):
    house_numbers = []
    streets = []
    wards = []
    districts = []
    cities = []
    progresses = []
    
    for address in df["address"]:
        address_info = get_location(address,api_key)
        house_numbers.append(address_info["House_number"])
        streets.append(address_info["Street"])
        wards.append(address_info["Ward"])
        districts.append(address_info["District"])
        cities.append(address_info["City"])
        progresses.append(address_info["progress"])
    
    df["House_number"] = house_numbers
    df["Street"] = streets
    df["Ward"] = wards
    df["District"] = districts
    df["City"] = cities
    df["progress"] = progresses

    return df

# %%
df_test = df

# %%
# Calculate the number of groups
num_groups = len(df_test) // 1000

# Calculate the number of remaining rows
remaining_rows = len(df_test) % 1000

# Create a list to store the new dataframes
dfs = []

# Split the dataframe into groups of two rows each
for i in range(num_groups):
    start_index = i * 1000
    end_index = start_index + 1000
    df_group = df_test[start_index:end_index].copy()
    dfs.append(df_group)

# Add the remaining rows to the last dataframe
if remaining_rows > 0:
    last_df = df_test[-remaining_rows:].copy()
    dfs.append(last_df)

# %%
# tiến hành chạy multi thread
import threading
import time

final = []
def out_put_with_time(df, api_key):
    start_time = time.time()
    out_put(df, api_key)
    end_time = time.time()
    execution_time = end_time - start_time
    print(f"Time: {execution_time/60} phút")

for df , api_key in zip(dfs, list_api_keys):
    thread = threading.Thread(target=out_put_with_time, args=(df,api_key))
    thread.start()
    thread.join()
    final.append(df)

print("Done")
# Out:
# Time: 5.266271853446961 phút
# Time: 5.30616602897644 phút
# Time: 4.032309138774872 phút
# Done

# %%
merged_df = pd.concat(final, ignore_index=True)

# %%
merged_df[merged_df["progress"] == "False"]
# Out:
# Empty DataFrame
# Columns: [Title, Price, Area, address, type, area_value, price_value_trieu, price_per_m2_final, House_number, Street, Ward, District, City, progress]
# Index: []

# %%
merged_df.head(5)
# Out:
#                                                Title                Price  \
# 0              CHO THUÊ CỬA HÀNG, KI ỐT TẠI VIỆT NAM  Giá: 20 triệu/tháng
# 1  CHO THUÊ 5X45M, 1 LẦU MẶT TIỀN MAI VĂN VĨNH, T...  Giá: 55 triệu/tháng
# 2  CHỦ GỬI NHÀ MẶT TIỀN 601 NGUYỄN DUY TRINH QUẬN...  Giá: 24 triệu/tháng
# 3  CHO THUÊ 300M2 CÓ PCCC ĐƯỜNG 4 LÀN TRUNG TÂM B...       Giá: 120 triệu
# 4  CHO THUÊ BIỆT THỰ -12,5X20- MẶT TIỀN NGUYỄN TH...   Giá: 4 triệu/tháng
#
#                 Area                                            address  \
# 0  Diện tích: 225 m²  Đường Mai Văn Vĩnh, Phường Tân Quy, Quận 7, Tp...
# 1  Diện tích: 142 m²  601, Nguyễn Duy Trinh, Phường Bình Trưng Đông ...
# 2  Diện tích: 300 m²  Đường Cầu Diễn, Phường Phúc Diễn, Bắc Từ Liêm,...
# 3  Diện tích: 260 m²  Đường Nguyễn Thành Ý, Phường Đa Kao, Quận 1, T...
# 4   Diện tích: 20 m²  1486A, Đường 3/2, Phường 2, Quận 11, Tp Hồ Chí...
#
#                                                 type  area_value  \
# 0  search?iCat=55&iCitId=0&iDisId=0&iWardId=0&iPr...       225.0
# 1  search?iCat=55&iCitId=0&iDisId=0&iWardId=0&iPr...       142.0
# 2  search?iCat=55&iCitId=0&iDisId=0&iWardId=0&iPr...       300.0
# 3  search?iCat=55&iCitId=0&iDisId=0&iWardId=0&iPr...       260.0
# 4  search?iCat=55&iCitId=0&iDisId=0&iWardId=0&iPr...        20.0
#
#    price_value_trieu  price_per_m2_final House_number                  Street  \
# 0               20.0        88888.888889                   Đường Mai Văn Vĩnh
# 1               55.0       387323.943662          601  Đường Nguyễn Duy Trinh
# 2               24.0        80000.000000                       Đường Cầu Diễn
# 3              120.0       461538.461538                 Đường Nguyễn Thành Ý
# 4                4.0       200000.000000       1168/2         Đường 3 Tháng 2
#
#                      Ward          District         City progress
# 0          Phường Tân Quy            Quận 7  Hồ Chí Minh     True
# 1  Phường Bình Trưng Đông           Thủ Đức  Hồ Chí Minh     True
# 2        Phường Phúc Diễn  Quận Bắc Từ Liêm       Hà Nội     True
# 3           Phường Đa Kao            Quận 1  Hồ Chí Minh     True
# 4               Phường 12           Quận 11  Hồ Chí Minh     True

# %%
merged_df[merged_df["Street"].str.contains("hẻm|ngách|ngõ", case=False)]
# Out:
#                                                   Title  \
# 5             CHO THUÊ MẶT BẰNG VỈA HÈ MẶT TIỀN QUẬN 11
# 20    NHÀ MẶT TIỀN LÊ THÁNH TÔN ĐỐI DIỆN CHỢ BẾN THÀ...
# 43    CHO THUÊ CĂN MẶT TIỀN KINH DOANH TẠI CHUNG CƯ ...
# 61    CẦN SANG KIOS MẶT TIỀN ĐƯỜNG DD5 KHU VUI CHƠI ...
# 80    CHO THUÊ NHÀ MẶT TIỀN KINH DOANH, ĐƯỜNG NGUYỄN...
# ...                                                 ...
# 2694  CHO THUÊ TÒA NHÀ 8 TẦNG 110 M2 MẶT PHỐ MẠC THÁ...
# 2708  CHÍNH CHỦ CHO THUÊ NHÀ MẶT TIỀN 474D QUANG TRU...
# 2724  CHÍNH CHỦ CẦN CHO THUÊ NHÀ MẶT PHỐ ĐƯỜNG PHAN ...
# 2743  SIÊU RẺ, TOÀ NHÀ VĂN PHÒNG HẠNG A MP VŨ TÔNG P...
# 2763  CHO THUÊ NHÀ MT NGUYỄN ẢNH THỦ, DT: 12M X 15M,...
#
#                       Price               Area  \
# 5     Giá: 18,5 triệu/tháng   Diện tích: 49 m²
# 20      Giá: 28 triệu/tháng  Diện tích: 200 m²
# 43      Giá: 28 triệu/tháng  Diện tích: 200 m²
# 61       Giá: 5 triệu/tháng   Diện tích: 27 m²
# 80       Giá: 5 triệu/tháng   Diện tích: 70 m²
# ...                     ...                ...
# 2694    Giá: 17 triệu/tháng  Diện tích: 100 m²
# 2708    Giá: 50 triệu/tháng   Diện tích: 84 m²
# 2724    Giá: 30 triệu/tháng   Diện tích: 45 m²
# 2743         Giá: 220 triệu  Diện tích: 600 m²
# 2763    Giá: 30 triệu/tháng  Diện tích: 150 m²
#
#                                                 address  \
# 5     Cách mạng tháng 8, Phường 15, Quận 10, Tp Hồ C...
# 20    Nguyễn Đình Chiểu, Phường 3, Quận 3, Tp Hồ Chí...
# 43    Nguyễn Đình Chiểu, Phường 3, Quận 3, Tp Hồ Chí...
# 61    Trần Vĩnh Khiết, Phường An Bình, Quận Ninh Kiề...
# 80    Hẻm Lò Mổ, Phường An Khánh, Quận Ninh Kiều, Cầ...
# ...                                                 ...
# 2694       Đường Ái Mộ, Phường Bồ Đề, Long Biên, Hà Nội
# 2708  Đường Thích Quảng Đức, Phường 3, Phú Nhuận, Hồ...
# 2724  Đường Trần Thái Tông, Phường Dịch Vọng Hậu, Cầ...
# 2743        Đường Láng, Phường Láng Hạ, Đống Đa, Hà Nội
# 2763  Đường Trần Thái Tông, Phường Dịch Vọng Hậu, Cầ...
#
#                                                    type  area_value  \
# 5     search?iCat=55&iCitId=0&iDisId=0&iWardId=0&iPr...        49.0
# 20    search?iCat=55&iCitId=0&iDisId=0&iWardId=0&iPr...       200.0
# 43    search?iCat=55&iCitId=0&iDisId=0&iWardId=0&iPr...       200.0
# 61    search?iCat=55&iCitId=0&iDisId=0&iWardId=0&iPr...        27.0
# 80    search?iCat=55&iCitId=0&iDisId=0&iWardId=0&iPr...        70.0
# ...                                                 ...         ...
# 2694                                        nha_mat_pho       100.0
# 2708                                        nha_mat_pho        84.0
# 2724                                        nha_mat_pho        45.0
# 2743                                        nha_mat_pho       600.0
# 2763                                        nha_mat_pho       150.0
#
#       price_value_trieu  price_per_m2_final House_number  \
# 5                  18.5       377551.020408           8E
# 20                 28.0       140000.000000
# 43                 28.0       140000.000000
# 61                  5.0       185185.185185
# 80                  5.0        71428.571429
# ...                 ...                 ...          ...
# 2694               17.0       170000.000000
# 2708               50.0       595238.095238
# 2724               30.0       666666.666667
# 2743              220.0       366666.666667
# 2763               30.0       200000.000000
#
#                              Street              Ward        District  \
# 5       Hẻm 575 Cách Mạng Tháng Tám         Phường 15         Quận 10
# 20      Hẻm 491/5 Nguyễn Đình Chiểu          Phường 2          Quận 3
# 43      Hẻm 491/5 Nguyễn Đình Chiểu          Phường 2          Quận 3
# 61             Hẻm 6 Trần Vĩnh Kiết    Phường An Bình  Quận Ninh Kiều
# 80                        Hẻm Lò Mổ   Phường An Khánh  Quận Ninh Kiều
# ...                             ...               ...             ...
# 2694                   Ngõ 99 Ái Mộ      Phường Bồ Đề  Quận Long Biên
# 2708  Hẻm 5 Đường 3 Thích Quảng Đức          Phường 3  Quận Phú Nhuận
# 2724    Hẻm 35 Đường Trần Thái Tông  Phường Dịch Vọng   Quận Cầu Giấy
# 2743             Ngõ 508 Đường Láng    Phường Láng Hạ    Quận Đống Đa
# 2763    Hẻm 35 Đường Trần Thái Tông  Phường Dịch Vọng   Quận Cầu Giấy
#
#              City progress
# 5     Hồ Chí Minh     True
# 20    Hồ Chí Minh     True
# 43    Hồ Chí Minh     True
# 61        Cần Thơ     True
# 80        Cần Thơ     True
# ...           ...      ...
# 2694       Hà Nội     True
# 2708  Hồ Chí Minh     True
# 2724       Hà Nội     True
# 2743       Hà Nội     True
# 2763       Hà Nội     True
#
# [169 rows x 14 columns]

# %%
import re

# %%
def cleaning_street(street):
    if isinstance(street, str):
        st = re.sub("(Hẻm|Ngõ|Ngách) \d+\/*\d*\/*\d* ", "", street)
        st = re.sub("(Hẻm T\d+)|Hẻm \d+[A-Za-z] ", "", st)
        st = re.sub(r"(30\/4|30\s(th[aá]ng\s)?4|30\s(th[aá]ng\s)?tư)", "Đường 30 Tháng 4", st, flags=re.IGNORECASE)
        st = re.sub(r"(3\/2|3\s(th[aá]ng\s)?2|3\s(th[aá]ng\s)?hai)", "Đường 3 Tháng 2", st, flags=re.IGNORECASE)
        st = re.sub(r"\bQL\.", "Quốc Lộ ", st)
        st = re.sub("-", "/", st)
        st = st.strip()  # Loại bỏ khoảng trắng ở hai đầu của đường dẫn
        lower_text = st.lower()
        if not re.search(r'^chung cư|^hẻm|^ấp|^khu phố|^phố|^quốc lộ|^tổ', lower_text) and not re.search(r'^đường', lower_text):
            st = "Đường " + st
        return st
    return street

# %%
merged_df["cleaned_street"] = merged_df.apply(lambda x: cleaning_street(x.Street), axis=1)

# %%
merged_df.to_excel(r"C:\Users\thinh.lv\Desktop\Adhoc\all_bds_sosanhnha_v2_clean.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# IllegalCharacterError                     Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 merged_df.to_excel(r"C:\Users\thinh.lv\Desktop\Adhoc\all_bds_sosanhnha_v2_clean.xlsx", index=False)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:2374, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2361 from pandas.io.formats.excel import ExcelFormatter
#    2363 formatter = ExcelFormatter(
#    2364     df,
#    2365     na_rep=na_rep,
#    (...)
#    2372     inf_rep=inf_rep,
#    2373 )
# -> 2374 formatter.write(
#    2375     excel_writer,
#    2376     sheet_name=sheet_name,
#    2377     startrow=startrow,
#    2378     startcol=startcol,
#    2379     freeze_panes=freeze_panes,
#    2380     engine=engine,
#    2381     storage_options=storage_options,
#    2382 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\formats\excel.py:950, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     947     need_save = True
#     949 try:
# --> 950     writer._write_cells(
#     951         formatted_cells,
#     952         sheet_name,
#     953         startrow=startrow,
#     954         startcol=startcol,
#     955         freeze_panes=freeze_panes,
#     956     )
#     957 finally:
#     958     # make sure to close opened file handles
#     959     if need_save:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\excel\_openpyxl.py:496, in OpenpyxlWriter._write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#     492 for cell in cells:
#     493     xcell = wks.cell(
#     494         row=startrow + cell.row + 1, column=startcol + cell.col + 1
#     495     )
# --> 496     xcell.value, fmt = self._value_with_fmt(cell.val)
#     497     if fmt:
#     498         xcell.number_format = fmt
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\openpyxl\cell\cell.py:218, in Cell.value(self, value)
#     215 @value.setter
#     216 def value(self, value):
#     217     """Set the value and infer type and display options."""
# --> 218     self._bind_value(value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\openpyxl\cell\cell.py:197, in Cell._bind_value(self, value)
#     194         self.number_format = get_time_format(t)
#     196 elif dt == "s" and not isinstance(value, CellRichText):
# --> 197     value = self.check_string(value)
#     198     if len(value) > 1 and value.startswith("="):
#     199         self.data_type = 'f'
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\openpyxl\cell\cell.py:165, in Cell.check_string(self, value)
#     163 value = value[:32767]
#     164 if next(ILLEGAL_CHARACTERS_RE.finditer(value), None):
# --> 165     raise IllegalCharacterError(f"{value} cannot be used in worksheets.")
#     166 return value
#
# MẶT BẰNG 20X25 MT HOÀNG VĂN THỤ QUẬN PHÚ NHUẬN cannot be used in worksheets.

# %%
merged_df.to_csv(r"C:\Users\thinh.lv\Desktop\Adhoc\all_bds_sosanhnha_v2_clean.csv", index=False)
